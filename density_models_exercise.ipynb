# %% [markdown]
# ## Density Models Assignment

# %%
# import matplotlib
import matplotlib.pyplot as plt

# set figure size
plt.rcParams["figure.figsize"] = (12,8)

#import numpy
import numpy as np

# from sklearn import make_blobs
from sklearn.datasets import make_blobs

# import DBSCAN
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Task: Generate clusters with make_blobs function
#
# Use the following settings:
#    * n_samples=150,
#    * n_features=2,
#    * centers=3,
#    * cluster_std=0.6,
#    * random_state=0

# %%
X, y = make_blobs(n_samples=150,
                  n_features=2,
                  centers=3,
                  cluster_std=0.6,
                  random_state=0)

# %% [markdown]
# * plot data points

# %%
# set figure size
plt.rcParams["figure.figsize"] = (12,8)

# plot clusters
plt.scatter(X[:,0],
            X[:,1],
            c='black',
            marker='o')
plt.grid()
plt.show()

# %% [markdown]
# * define function plot_clusters

# %%
def plot_clusters(X,y_res, plt_cluster_centers = False):
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster,0]
        y = X[y_res == cluster,1]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x,
                    y,
                    s=50,
                    marker='s',
                    label=f'cluster {cluster}')

    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker='*',
                    c='red',
                    s=250,
                    label='centroids')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Objective:
# Try to find optimal settings of `eps` and `min_samples` params of DBSCAN. You can iterate over multiple parameters combinations and plot the clustering results.

# %% [markdown]
# * define params space: two lists with `eps` and `min_samples` respectively

# %%
eps=[0.5,0.6,0.7]
min_samples=[3,4,5]

# %% [markdown]
# * combinations (hint: use 'product' function from 'itertools')

# %%
from itertools import product

for i in product(eps,min_samples):
    print(i)
    db = DBSCAN(eps=i[0],
                min_samples=i[1],
                metric='euclidean')
    y_db = db.fit_predict(X)
    plot_clusters(X,y_db,False)
# Out:
# (0.5, 3)
# (0.5, 4)
# (0.5, 5)
# (0.6, 3)
# (0.6, 4)
# (0.6, 5)
# (0.7, 3)
# (0.7, 4)
# (0.7, 5)

# %% [markdown]
# - fit DBSCAN for each combinations and plot the results

# %% [markdown]
# Best results are achieved with epsilon = 0.7 and min_samples = 5
